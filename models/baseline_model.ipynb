# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train = pd.read_csv('../data/processed/X_train.csv')
X_test = pd.read_csv('../data/processed/X_test.csv')
y_train = pd.read_csv('../data/processed/y_train.csv')
y_test = pd.read_csv('../data/processed/y_test.csv')

# Convert to float32 to ensure compatibility with TensorFlow
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

print("Data loaded and converted to float32 successfully.")
print("X_train shape:", X_train.shape)
# Out:
# Data loaded and converted to float32 successfully.
# X_train shape: (1106, 53)

# %%
# Build Baseline Model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)  # Output layer for regression
])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                3456
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5569 (21.75 KB)
# Trainable params: 5569 (21.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile Model
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mean_absolute_error'])

# %%
# Train Model
history = model.fit(X_train, y_train,
                    epochs=100,
                    validation_data=(X_test, y_test),
                    verbose=1)
# Out:
# Epoch 1/100
# 35/35 [==============================] - 0s 4ms/step - loss: 3146.4500 - mean_absolute_error: 36.6528 - val_loss: 170.6718 - val_mean_absolute_error: 9.7477
# Epoch 2/100
# 35/35 [==============================] - 0s 2ms/step - loss: 101.9709 - mean_absolute_error: 7.2890 - val_loss: 52.8119 - val_mean_absolute_error: 4.5237
# Epoch 3/100
# 35/35 [==============================] - 0s 1ms/step - loss: 38.6087 - mean_absolute_error: 4.1777 - val_loss: 34.4830 - val_mean_absolute_error: 3.5867
# Epoch 4/100
# 35/35 [==============================] - 0s 2ms/step - loss: 25.2837 - mean_absolute_error: 3.3470 - val_loss: 25.8975 - val_mean_absolute_error: 3.0974
# Epoch 5/100
# 35/35 [==============================] - 0s 1ms/step - loss: 18.9602 - mean_absolute_error: 2.7358 - val_loss: 22.7162 - val_mean_absolute_error: 2.9240
# Epoch 6/100
# 35/35 [==============================] - 0s 2ms/step - loss: 17.5283 - mean_absolute_error: 2.6761 - val_loss: 20.1685 - val_mean_absolute_error: 2.7215
# Epoch 7/100
# 35/35 [==============================] - 0s 1ms/step - loss: 16.0099 - mean_absolute_error: 2.6947 - val_loss: 19.5112 - val_mean_absolute_error: 2.6730
# Epoch 8/100
# 35/35 [==============================] - 0s 1ms/step - loss: 15.4873 - mean_absolute_error: 2.6096 - val_loss: 16.5440 - val_mean_absolute_error: 2.3989
# Epoch 9/100
# 35/35 [==============================] - 0s 1ms/step - loss: 16.7820 - mean_absolute_error: 2.7951 - val_loss: 15.4588 - val_mean_absolute_error: 2.3363
# Epoch 10/100
# 35/35 [==============================] - 0s 2ms/step - loss: 12.8450 - mean_absolute_error: 2.3764 - val_loss: 16.0507 - val_mean_absolute_error: 2.7362
# Epoch 11/100
# 35/35 [==============================] - 0s 2ms/step - loss: 15.3811 - mean_absolute_error: 2.8298 - val_loss: 12.8040 - val_mean_absolute_error: 2.1113
# Epoch 12/100
# 35/35 [==============================] - 0s 1ms/step - loss: 9.9172 - mean_absolute_error: 2.0670 - val_loss: 13.1902 - val_mean_absolute_error: 2.4876
# Epoch 13/100
# 35/35 [==============================] - 0s 2ms/step - loss: 9.1673 - mean_absolute_error: 1.9974 - val_loss: 12.2373 - val_mean_absolute_error: 2.3465
# Epoch 14/100
# 35/35 [==============================] - 0s 2ms/step - loss: 8.6001 - mean_absolute_error: 1.9808 - val_loss: 14.5272 - val_mean_absolute_error: 2.9523
# Epoch 15/100
# 35/35 [==============================] - 0s 2ms/step - loss: 9.3967 - mean_absolute_error: 2.0829 - val_loss: 10.9458 - val_mean_absolute_error: 2.2653
# Epoch 16/100
# 35/35 [==============================] - 0s 2ms/step - loss: 7.3447 - mean_absolute_error: 1.7938 - val_loss: 9.0675 - val_mean_absolute_error: 1.7998
# Epoch 17/100
# 35/35 [==============================] - 0s 1ms/step - loss: 7.0249 - mean_absolute_error: 1.8018 - val_loss: 10.1019 - val_mean_absolute_error: 1.8739
# Epoch 18/100
# 35/35 [==============================] - 0s 2ms/step - loss: 6.9226 - mean_absolute_error: 1.7092 - val_loss: 9.1740 - val_mean_absolute_error: 2.0655
# Epoch 19/100
# 35/35 [==============================] - 0s 2ms/step - loss: 6.3847 - mean_absolute_error: 1.7458 - val_loss: 8.3363 - val_mean_absolute_error: 1.4969
# Epoch 20/100
# 35/35 [==============================] - 0s 1ms/step - loss: 6.1988 - mean_absolute_error: 1.7268 - val_loss: 6.9722 - val_mean_absolute_error: 1.4984
# Epoch 21/100
# 35/35 [==============================] - 0s 1ms/step - loss: 7.0522 - mean_absolute_error: 1.9402 - val_loss: 7.2550 - val_mean_absolute_error: 1.7812
# Epoch 22/100
# 35/35 [==============================] - 0s 1ms/step - loss: 7.1015 - mean_absolute_error: 1.8960 - val_loss: 7.3816 - val_mean_absolute_error: 1.7001
# Epoch 23/100
# 35/35 [==============================] - 0s 1ms/step - loss: 6.9902 - mean_absolute_error: 1.9532 - val_loss: 11.4496 - val_mean_absolute_error: 2.1953
# Epoch 24/100
# 35/35 [==============================] - 0s 1ms/step - loss: 6.1338 - mean_absolute_error: 1.7561 - val_loss: 10.2206 - val_mean_absolute_error: 2.5607
# Epoch 25/100
# 35/35 [==============================] - 0s 1ms/step - loss: 5.8822 - mean_absolute_error: 1.8145 - val_loss: 7.3249 - val_mean_absolute_error: 1.7579
# Epoch 26/100
# 35/35 [==============================] - 0s 1ms/step - loss: 5.0108 - mean_absolute_error: 1.5976 - val_loss: 7.2709 - val_mean_absolute_error: 2.0037
# Epoch 27/100
# 35/35 [==============================] - 0s 2ms/step - loss: 5.1422 - mean_absolute_error: 1.5775 - val_loss: 7.2791 - val_mean_absolute_error: 1.7920
# Epoch 28/100
# 35/35 [==============================] - 0s 1ms/step - loss: 5.6257 - mean_absolute_error: 1.7080 - val_loss: 6.1025 - val_mean_absolute_error: 1.8077
# Epoch 29/100
# 35/35 [==============================] - 0s 2ms/step - loss: 4.1708 - mean_absolute_error: 1.4554 - val_loss: 6.4382 - val_mean_absolute_error: 1.6979
# Epoch 30/100
# 35/35 [==============================] - 0s 2ms/step - loss: 4.2766 - mean_absolute_error: 1.4216 - val_loss: 4.2247 - val_mean_absolute_error: 1.1144
# Epoch 31/100
# 35/35 [==============================] - 0s 2ms/step - loss: 3.5697 - mean_absolute_error: 1.3196 - val_loss: 6.2413 - val_mean_absolute_error: 1.9008
# Epoch 32/100
# 35/35 [==============================] - 0s 2ms/step - loss: 3.5158 - mean_absolute_error: 1.3466 - val_loss: 3.9866 - val_mean_absolute_error: 1.2672
# Epoch 33/100
# 35/35 [==============================] - 0s 1ms/step - loss: 4.1470 - mean_absolute_error: 1.4949 - val_loss: 6.2875 - val_mean_absolute_error: 2.1030
# Epoch 34/100
# 35/35 [==============================] - 0s 2ms/step - loss: 5.6295 - mean_absolute_error: 1.8372 - val_loss: 4.5432 - val_mean_absolute_error: 1.6609
# Epoch 35/100
# 35/35 [==============================] - 0s 1ms/step - loss: 3.0606 - mean_absolute_error: 1.2023 - val_loss: 3.4051 - val_mean_absolute_error: 1.2017
# Epoch 36/100
# 35/35 [==============================] - 0s 2ms/step - loss: 2.9254 - mean_absolute_error: 1.2261 - val_loss: 3.5486 - val_mean_absolute_error: 1.0316
# Epoch 37/100
# 35/35 [==============================] - 0s 2ms/step - loss: 2.8180 - mean_absolute_error: 1.2117 - val_loss: 2.9642 - val_mean_absolute_error: 1.0406
# Epoch 38/100
# 35/35 [==============================] - 0s 1ms/step - loss: 3.0651 - mean_absolute_error: 1.2562 - val_loss: 6.8680 - val_mean_absolute_error: 1.9756
# Epoch 39/100
# 35/35 [==============================] - 0s 2ms/step - loss: 4.1209 - mean_absolute_error: 1.5039 - val_loss: 3.0289 - val_mean_absolute_error: 1.1835
# Epoch 40/100
# 35/35 [==============================] - 0s 2ms/step - loss: 2.7936 - mean_absolute_error: 1.2464 - val_loss: 2.9969 - val_mean_absolute_error: 0.8765
# Epoch 41/100
# 35/35 [==============================] - 0s 2ms/step - loss: 3.6923 - mean_absolute_error: 1.4016 - val_loss: 2.9140 - val_mean_absolute_error: 1.1602
# Epoch 42/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.7579 - mean_absolute_error: 1.2085 - val_loss: 3.4278 - val_mean_absolute_error: 1.2354
# Epoch 43/100
# 35/35 [==============================] - 0s 2ms/step - loss: 4.3502 - mean_absolute_error: 1.5772 - val_loss: 3.7259 - val_mean_absolute_error: 1.5544
# Epoch 44/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.7113 - mean_absolute_error: 1.2398 - val_loss: 2.3777 - val_mean_absolute_error: 0.8426
# Epoch 45/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.1627 - mean_absolute_error: 1.0806 - val_loss: 2.8941 - val_mean_absolute_error: 1.2568
# Epoch 46/100
# 35/35 [==============================] - 0s 2ms/step - loss: 2.3265 - mean_absolute_error: 1.1402 - val_loss: 5.0256 - val_mean_absolute_error: 1.6033
# Epoch 47/100
# 35/35 [==============================] - 0s 1ms/step - loss: 3.6077 - mean_absolute_error: 1.4138 - val_loss: 3.5589 - val_mean_absolute_error: 1.2896
# Epoch 48/100
# 35/35 [==============================] - 0s 2ms/step - loss: 1.8673 - mean_absolute_error: 0.9843 - val_loss: 2.3717 - val_mean_absolute_error: 1.0557
# Epoch 49/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.0334 - mean_absolute_error: 1.0552 - val_loss: 2.0469 - val_mean_absolute_error: 0.8259
# Epoch 50/100
# 35/35 [==============================] - 0s 2ms/step - loss: 2.0674 - mean_absolute_error: 1.0590 - val_loss: 2.0935 - val_mean_absolute_error: 0.9605
# Epoch 51/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.3688 - mean_absolute_error: 1.1543 - val_loss: 2.1237 - val_mean_absolute_error: 0.9830
# Epoch 52/100
# 35/35 [==============================] - 0s 1ms/step - loss: 3.4163 - mean_absolute_error: 1.4476 - val_loss: 2.0939 - val_mean_absolute_error: 0.8810
# Epoch 53/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.9707 - mean_absolute_error: 1.0514 - val_loss: 6.1871 - val_mean_absolute_error: 1.9585
# Epoch 54/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.0645 - mean_absolute_error: 1.0711 - val_loss: 1.8144 - val_mean_absolute_error: 0.7590
# Epoch 55/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.7585 - mean_absolute_error: 0.9899 - val_loss: 1.5639 - val_mean_absolute_error: 0.7828
# Epoch 56/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.5892 - mean_absolute_error: 1.1537 - val_loss: 1.7353 - val_mean_absolute_error: 0.9115
# Epoch 57/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.1934 - mean_absolute_error: 0.9912 - val_loss: 2.6832 - val_mean_absolute_error: 1.2361
# Epoch 58/100
# 35/35 [==============================] - 0s 2ms/step - loss: 2.0861 - mean_absolute_error: 1.0259 - val_loss: 3.0238 - val_mean_absolute_error: 1.3245
# Epoch 59/100
# 35/35 [==============================] - 0s 1ms/step - loss: 4.9081 - mean_absolute_error: 1.6657 - val_loss: 3.3106 - val_mean_absolute_error: 1.3635
# Epoch 60/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.7063 - mean_absolute_error: 1.2423 - val_loss: 1.4445 - val_mean_absolute_error: 0.6896
# Epoch 61/100
# 35/35 [==============================] - 0s 2ms/step - loss: 1.4250 - mean_absolute_error: 0.8957 - val_loss: 1.8723 - val_mean_absolute_error: 0.9390
# Epoch 62/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.1972 - mean_absolute_error: 0.8147 - val_loss: 1.4000 - val_mean_absolute_error: 0.7526
# Epoch 63/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.2767 - mean_absolute_error: 0.8434 - val_loss: 2.2768 - val_mean_absolute_error: 1.0782
# Epoch 64/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.6932 - mean_absolute_error: 0.9980 - val_loss: 1.7960 - val_mean_absolute_error: 1.0061
# Epoch 65/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.5568 - mean_absolute_error: 1.2589 - val_loss: 3.6845 - val_mean_absolute_error: 1.6469
# Epoch 66/100
# 35/35 [==============================] - 0s 2ms/step - loss: 1.5967 - mean_absolute_error: 0.9480 - val_loss: 4.2580 - val_mean_absolute_error: 1.8022
# Epoch 67/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.4014 - mean_absolute_error: 0.9088 - val_loss: 2.5155 - val_mean_absolute_error: 1.2616
# Epoch 68/100
# 35/35 [==============================] - 0s 2ms/step - loss: 2.0345 - mean_absolute_error: 1.1155 - val_loss: 4.1748 - val_mean_absolute_error: 1.6591
# Epoch 69/100
# 35/35 [==============================] - 0s 1ms/step - loss: 3.6843 - mean_absolute_error: 1.5564 - val_loss: 2.0582 - val_mean_absolute_error: 0.9985
# Epoch 70/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.6996 - mean_absolute_error: 0.9893 - val_loss: 1.3596 - val_mean_absolute_error: 0.7856
# Epoch 71/100
# 35/35 [==============================] - 0s 1ms/step - loss: 3.5331 - mean_absolute_error: 1.4554 - val_loss: 5.4005 - val_mean_absolute_error: 1.7071
# Epoch 72/100
# 35/35 [==============================] - 0s 1ms/step - loss: 7.1768 - mean_absolute_error: 2.0689 - val_loss: 7.0991 - val_mean_absolute_error: 2.2531
# Epoch 73/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.1829 - mean_absolute_error: 1.1266 - val_loss: 1.7792 - val_mean_absolute_error: 0.9215
# Epoch 74/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.8927 - mean_absolute_error: 1.0859 - val_loss: 1.2405 - val_mean_absolute_error: 0.7693
# Epoch 75/100
# 35/35 [==============================] - 0s 2ms/step - loss: 1.1259 - mean_absolute_error: 0.8023 - val_loss: 2.6318 - val_mean_absolute_error: 1.2639
# Epoch 76/100
# 35/35 [==============================] - 0s 2ms/step - loss: 1.4929 - mean_absolute_error: 0.9062 - val_loss: 1.9078 - val_mean_absolute_error: 1.0643
# Epoch 77/100
# 35/35 [==============================] - 0s 2ms/step - loss: 1.3384 - mean_absolute_error: 0.8934 - val_loss: 1.6891 - val_mean_absolute_error: 0.9324
# Epoch 78/100
# 35/35 [==============================] - 0s 2ms/step - loss: 1.1470 - mean_absolute_error: 0.8181 - val_loss: 1.3514 - val_mean_absolute_error: 0.7124
# Epoch 79/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.1538 - mean_absolute_error: 0.8043 - val_loss: 1.1035 - val_mean_absolute_error: 0.6394
# Epoch 80/100
# 35/35 [==============================] - 0s 2ms/step - loss: 1.5043 - mean_absolute_error: 0.9371 - val_loss: 1.3749 - val_mean_absolute_error: 0.7557
# Epoch 81/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.5409 - mean_absolute_error: 0.9424 - val_loss: 5.9892 - val_mean_absolute_error: 2.1999
# Epoch 82/100
# 35/35 [==============================] - 0s 2ms/step - loss: 1.4719 - mean_absolute_error: 0.9322 - val_loss: 1.0123 - val_mean_absolute_error: 0.6938
# Epoch 83/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.0190 - mean_absolute_error: 1.1169 - val_loss: 2.0650 - val_mean_absolute_error: 1.0961
# Epoch 84/100
# 35/35 [==============================] - 0s 2ms/step - loss: 0.8564 - mean_absolute_error: 0.7036 - val_loss: 1.2033 - val_mean_absolute_error: 0.6896
# Epoch 85/100
# 35/35 [==============================] - 0s 2ms/step - loss: 2.7053 - mean_absolute_error: 1.2322 - val_loss: 12.6192 - val_mean_absolute_error: 2.9940
# Epoch 86/100
# 35/35 [==============================] - 0s 1ms/step - loss: 4.6854 - mean_absolute_error: 1.7153 - val_loss: 1.2952 - val_mean_absolute_error: 0.8474
# Epoch 87/100
# 35/35 [==============================] - 0s 2ms/step - loss: 1.5676 - mean_absolute_error: 0.9042 - val_loss: 1.8826 - val_mean_absolute_error: 1.0530
# Epoch 88/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.1992 - mean_absolute_error: 1.1677 - val_loss: 4.2230 - val_mean_absolute_error: 1.8439
# Epoch 89/100
# 35/35 [==============================] - 0s 2ms/step - loss: 3.7251 - mean_absolute_error: 1.5752 - val_loss: 6.0206 - val_mean_absolute_error: 2.2398
# Epoch 90/100
# 35/35 [==============================] - 0s 1ms/step - loss: 8.1252 - mean_absolute_error: 2.3423 - val_loss: 4.7308 - val_mean_absolute_error: 1.8520
# Epoch 91/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.7554 - mean_absolute_error: 1.0050 - val_loss: 1.3098 - val_mean_absolute_error: 0.8183
# Epoch 92/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.1892 - mean_absolute_error: 0.8298 - val_loss: 1.3129 - val_mean_absolute_error: 0.7974
# Epoch 93/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.7322 - mean_absolute_error: 0.9673 - val_loss: 1.1817 - val_mean_absolute_error: 0.7627
# Epoch 94/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.0997 - mean_absolute_error: 0.8243 - val_loss: 1.7886 - val_mean_absolute_error: 0.9987
# Epoch 95/100
# 35/35 [==============================] - 0s 1ms/step - loss: 2.1870 - mean_absolute_error: 1.1323 - val_loss: 1.0824 - val_mean_absolute_error: 0.6781
# Epoch 96/100
# 35/35 [==============================] - 0s 2ms/step - loss: 1.2017 - mean_absolute_error: 0.8578 - val_loss: 1.3222 - val_mean_absolute_error: 0.8761
# Epoch 97/100
# 35/35 [==============================] - 0s 1ms/step - loss: 4.3405 - mean_absolute_error: 1.6284 - val_loss: 4.9516 - val_mean_absolute_error: 1.9719
# Epoch 98/100
# 35/35 [==============================] - 0s 2ms/step - loss: 6.1804 - mean_absolute_error: 2.0322 - val_loss: 4.0508 - val_mean_absolute_error: 1.5302
# Epoch 99/100
# 35/35 [==============================] - 0s 2ms/step - loss: 4.9345 - mean_absolute_error: 1.7712 - val_loss: 1.5398 - val_mean_absolute_error: 0.9679
# Epoch 100/100
# 35/35 [==============================] - 0s 1ms/step - loss: 1.4517 - mean_absolute_error: 0.9267 - val_loss: 0.9802 - val_mean_absolute_error: 0.6639

# %%
# Evaluate Model
loss, mae = model.evaluate(X_test, y_test)
print(f"Test MAE: {mae}")
# Out:
# 7/7 [==============================] - 0s 1ms/step - loss: 0.9802 - mean_absolute_error: 0.6639
# Test MAE: 0.6638832688331604
